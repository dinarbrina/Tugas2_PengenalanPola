# %%
import sys
# !{sys.executable} -m pip install mglearn

# %%
from sklearn.datasets import load_diabetes
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mglearn
from pandas.plotting import scatter_matrix

# %%
diabetes_dataset = load_diabetes()

# %%
print("Type of target: {}".format(type(diabetes_dataset['target'])))
# Out:
# Type of target: <class 'numpy.ndarray'>

# %%
print("Shape of target: {}".format(diabetes_dataset['target'].shape))
# Out:
# Shape of target: (442,)

# %%
print("Target:\n{}".format(diabetes_dataset['target']))
# Out:
# Target:
# [151.  75. 141. 206. 135.  97. 138.  63. 110. 310. 101.  69. 179. 185.
#  118. 171. 166. 144.  97. 168.  68.  49.  68. 245. 184. 202. 137.  85.
#  131. 283. 129.  59. 341.  87.  65. 102. 265. 276. 252.  90. 100.  55.
#   61.  92. 259.  53. 190. 142.  75. 142. 155. 225.  59. 104. 182. 128.
#   52.  37. 170. 170.  61. 144.  52. 128.  71. 163. 150.  97. 160. 178.
#   48. 270. 202. 111.  85.  42. 170. 200. 252. 113. 143.  51.  52. 210.
#   65. 141.  55. 134.  42. 111.  98. 164.  48.  96.  90. 162. 150. 279.
#   92.  83. 128. 102. 302. 198.  95.  53. 134. 144. 232.  81. 104.  59.
#  246. 297. 258. 229. 275. 281. 179. 200. 200. 173. 180.  84. 121. 161.
#   99. 109. 115. 268. 274. 158. 107.  83. 103. 272.  85. 280. 336. 281.
#  118. 317. 235.  60. 174. 259. 178. 128.  96. 126. 288.  88. 292.  71.
#  197. 186.  25.  84.  96. 195.  53. 217. 172. 131. 214.  59.  70. 220.
#  268. 152.  47.  74. 295. 101. 151. 127. 237. 225.  81. 151. 107.  64.
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
diabetes_dataset['data'], diabetes_dataset['target'], random_state=0)

# %%
print("X_train shape: {}".format(X_train.shape))
print("y_train shape: {}".format(y_train.shape))
# Out:
# X_train shape: (331, 10)
# y_train shape: (331,)

# %%
print("X_test shape: {}".format(X_test.shape))
print("y_test shape: {}".format(y_test.shape))
# Out:
# X_test shape: (111, 10)
# y_test shape: (111,)

# %%
# create dataframe from data in X_train
# label the columns using the strings in iris_dataset.feature_names
iris_dataframe = pd.DataFrame(X_train, columns=diabetes_dataset.feature_names)
# create a scatter matrix from the dataframe, color by y_train
grr = scatter_matrix(iris_dataframe, c=y_train, figsize=(15, 15), marker='o',
hist_kwds={'bins': 20}, s=60, alpha=.8, cmap=mglearn.cm3)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
# Menampilkan 5 data pertama
print(X_test[:5])
# Out:
# [[ 0.01991321  0.05068012  0.10480869  0.0700723  -0.03596778 -0.0266789
#   -0.02499266 -0.00259226  0.00370906  0.04034337]
#  [-0.01277963 -0.04464164  0.06061839  0.05285804  0.04796534  0.02937467
#   -0.01762938  0.03430886  0.07020738  0.00720652]
#  [ 0.03807591  0.05068012  0.00888341  0.04252949 -0.04284755 -0.02104223
#   -0.03971921 -0.00259226 -0.01811369  0.00720652]
#  [-0.01277963 -0.04464164 -0.02345095 -0.04009893 -0.01670444  0.00463594
#   -0.01762938 -0.00259226 -0.03845972 -0.03835666]
#  [-0.02367725 -0.04464164  0.04552903  0.09072941 -0.01808039 -0.03544706
#    0.07072993 -0.03949338 -0.03452178 -0.00936191]]

# %%
X_new = np.array([[ 0.01991321,  0.05068012,  0.10480869,  0.0700723,  -0.03596778, -0.0266789,
  -0.02499266, -0.00259226,  0.00370906,  0.04034337]])
print("X_new.shape: {}".format(X_new.shape))
# Out:
# X_new.shape: (1, 10)

# %%
prediction = knn.predict(X_new)
print("Prediction: {}".format(prediction))
# Out:
# Prediction: [336.]

# %%
y_pred = knn.predict(X_test)
print("Test set predictions:\n {}".format(y_pred))
# Out:
# Test set predictions:
#  [336. 220. 118.  97. 293. 275.  96. 237.  95. 310. 182. 122. 178.  77.
#  332.  43.  68.  63.  99. 268. 252.  88. 225. 210. 229. 262. 170.  48.
#  166. 122. 237.  42. 185. 206.  67.  66. 174.  77.  88. 109. 128. 107.
#  262. 265. 122.  65. 148. 113.  51. 296. 225.  72. 216. 111. 280. 181.
#  121. 150.  67. 237. 310.  25. 140. 111. 265. 113.  31. 306. 229.  72.
#   84. 202.  53. 141. 187. 107. 116. 272. 332.  67.  67. 164.  52. 311.
#   94. 153. 129. 126.  94.  65.  85.  47.  52. 237.  79. 148. 232. 261.
#   83.  97.  66. 143. 241.  73. 275.  80. 306. 242. 144.  53. 129.]

# %%
print("Test set score: {:.2f}".format(np.mean(y_pred == y_test)))
# Out:
# Test set score: 0.01

# %%
print("Test set score: {:.2f}".format(knn.score(X_test, y_test)))
# Out:
# Test set score: 0.01

# %%
# Menampilkan nilai X_test, hasil prediksi, dan benar/salah hasil prediksi
for i in range(len(X_test)):
    print("Data {}: {} -> {} [{}]".format(i+1, X_test[i], y_pred[i], "Benar" if y_pred[i] == y_test[i] else "Salah"))
# Out:
# Data 1: [ 0.01991321  0.05068012  0.10480869  0.0700723  -0.03596778 -0.0266789
#  -0.02499266 -0.00259226  0.00370906  0.04034337] -> 336.0 [Salah]
# Data 2: [-0.01277963 -0.04464164  0.06061839  0.05285804  0.04796534  0.02937467
#  -0.01762938  0.03430886  0.07020738  0.00720652] -> 220.0 [Salah]
# Data 3: [ 0.03807591  0.05068012  0.00888341  0.04252949 -0.04284755 -0.02104223
#  -0.03971921 -0.00259226 -0.01811369  0.00720652] -> 118.0 [Salah]
# Data 4: [-0.01277963 -0.04464164 -0.02345095 -0.04009893 -0.01670444  0.00463594
#  -0.01762938 -0.00259226 -0.03845972 -0.03835666] -> 97.0 [Salah]
# Data 5: [-0.02367725 -0.04464164  0.04552903  0.09072941 -0.01808039 -0.03544706
#   0.07072993 -0.03949338 -0.03452178 -0.00936191] -> 293.0 [Salah]
# Data 6: [-0.02004471 -0.04464164  0.097264   -0.00567042 -0.00569682 -0.02386057
#  -0.02131102 -0.00259226  0.06168429  0.04034337] -> 275.0 [Benar]
# Data 7: [ 0.01628068 -0.04464164 -0.02884001 -0.00911327 -0.00432087 -0.00976889
# ...
